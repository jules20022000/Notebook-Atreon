# %% [markdown]
# # Try to predict score with unsupervised data (unlabeled data)

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn import preprocessing
from matplotlib import pyplot as plt


test_data = pd.read_csv("train_handmade.csv").drop(columns=["name", "severity score"], axis=1)
test_data.describe()
test_data
# Out:
#     sexe  age  general health  ease of activity  breathing problem  fatigue  \
# 0      1   75               5                 3                  8        8
# 1      0   59               7                 7                  3        3
# 2      0   50               6                 5                  4        4
# 3      1   25               8                 8                  0        1
# 4      0   21               8                 9                  1        4
# 5      0   28               8                 5                  2        5
# 6      0   19               9                10                  1        1
# 7      1   64               6                 3                  3        3
# 8      0   83               3                 0                 10       10
# 9      0   49               7                 3                  6        5
# 10     0   60               5                 1                  6        6
# 11     1   70               4                 6                  5        8
# 12     0   47               6                 2                  6        4
# 13     1   24               8                 3                  2        0
#
#     overall pain  concentration  sleep quality
# 0              4              3              9
# 1              3              6              4
# 2              3              7              8
# 3              1             10              9
# 4              3              7              8
# 5              0              7              3
# 6              2              7              8
# 7              8              7              9
# 8              9              2              4
# 9              1              8              5
# 10             3              5              5
# 11             8              3              5
# 12             3              8              7
# 13             3              2             10

# %%
scaler = preprocessing.MinMaxScaler()
test_data_normalized = scaler.fit_transform(test_data)
pd.DataFrame(test_data_normalized).describe()
# Out:
#                0          1          2          3          4          5  \
# count  14.000000  14.000000  14.000000  14.000000  14.000000  14.000000
# mean    0.357143   0.455357   0.571429   0.464286   0.407143   0.442857
# std     0.497245   0.336788   0.290257   0.302826   0.289467   0.287467
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.105469   0.375000   0.300000   0.200000   0.300000
# 50%     0.000000   0.476562   0.583333   0.400000   0.350000   0.400000
# 75%     1.000000   0.687500   0.833333   0.675000   0.600000   0.575000
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#                6          7          8
# count  14.000000  14.000000  14.000000
# mean    0.404762   0.482143   0.530612
# std     0.306954   0.309533   0.328780
# min     0.000000   0.000000   0.000000
# 25%     0.250000   0.187500   0.285714
# 50%     0.333333   0.625000   0.642857
# 75%     0.416667   0.625000   0.821429
# max     1.000000   1.000000   1.000000

# %%
inertia = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(test_data_normalized)
    kmeanModel.fit(test_data_normalized)
    inertia.append(kmeanModel.inertia_)

# %%
# Plot the elbow
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.show()

# %%
clusters = 5

kmeans = KMeans(n_clusters=clusters, random_state=0)
kmeans.fit(test_data)

print(test_data[["age", "general health", "ease of activity"]])
print(kmeans.labels_)
# Out:
#     age  general health  ease of activity
# 0    75               5                 3
# 1    59               7                 7
# 2    50               6                 5
# 3    25               8                 8
# 4    21               8                 9
# 5    28               8                 5
# 6    19               9                10
# 7    64               6                 3
# 8    83               3                 0
# 9    49               7                 3
# 10   60               5                 1
# 11   70               4                 6
# 12   47               6                 2
# 13   24               8                 3
# [2 0 3 1 1 1 1 0 4 3 0 2 3 1]
