# %% [markdown]
# # Try to predict score with unsupervised data (unlabeled data)

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn import preprocessing
from matplotlib import pyplot as plt


test_data = pd.read_csv("train_handmade.csv", sep=";").drop(columns=["name", "severity score"], axis=1)
test_data.describe()
test_data
# Out:
#     sexe  age  general health  ease of activity  breathing problem  fatigue  \
# 0      1   75               5                 3                  8        8
# 1      0   59               7                 7                  3        3
# 2      0   50               6                 5                  4        4
# 3      1   25               8                 8                  0        1
# 4      0   21               8                 9                  1        4
# 5      0   28               8                 5                  2        5
# 6      0   19               9                10                  1        1
# 7      1   64               6                 3                  3        3
# 8      0   83               3                 0                 10       10
# 9      0   49               7                 3                  6        5
# 10     0   60               5                 1                  6        6
# 11     1   70               4                 6                  5        8
# 12     0   47               6                 2                  6        4
# 13     1   24               8                 3                  2        0
# 14     0   22               5                 1                  7        6
# 15     1   18               8                 3                  2        3
# 16     1   56               8                 9                  2        2
# 17     1   80               3                 2                  7        6
# 18     0   50               3                 2                  8        8
# 19     0   47               7                 8                  3        3
# 20     1   36               5                 6                  5        4
# 21     0   32               6                 4                  1        6
# 22     0   71               1                 3                  8        9
# 23     0   67               4                 6                  5        8
# 24     1   63               7                 7                  3        2
# 25     1   26               8                 2                  2        2
# 26     0   28               9                 9                  1        0
# 27     1   45               3                 6                  8        8
# 28     0   20               9                 1                  0        0
# 29     1   65               2                 3                  9       10
#
#     overall pain  concentration  sleep quality
# 0              4              3              9
# 1              3              6              4
# 2              3              7              8
# 3              1             10              9
# 4              3              7              8
# 5              0              7              3
# 6              2              7              8
# 7              8              7              9
# 8              9              2              4
# 9              1              8              5
# 10             3              5              5
# 11             8              3              5
# 12             3              8              7
# 13             3              2             10
# 14             3              7              6
# 15             3              6              5
# 16             2              5              4
# 17             6              5              5
# 18             3              7              7
# 19             6              6              4
# 20             8              3              2
# 21             2              4             10
# 22             7              5              4
# 23             5              5              3
# 24             3              5              8
# 25             3             10              8
# 26             1              6             10
# 27             3              4              7
# 28             0              8             10
# 29             5              5              3

# %%
scaler = preprocessing.MinMaxScaler()
test_data_normalized = scaler.fit_transform(test_data)
pd.DataFrame(test_data_normalized).describe()
# Out:
#                0          1          2          3          4          5  \
# count  30.000000  30.000000  30.000000  30.000000  30.000000  30.000000
# mean    0.433333   0.441026   0.616667   0.456667   0.426667   0.463333
# std     0.504007   0.314729   0.282258   0.284888   0.292355   0.302271
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.130769   0.406250   0.225000   0.200000   0.225000
# 50%     0.000000   0.461538   0.625000   0.350000   0.350000   0.400000
# 75%     1.000000   0.703846   0.875000   0.675000   0.675000   0.750000
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#                6          7          8
# count  30.000000  30.000000  30.000000
# mean    0.411111   0.470833   0.541667
# std     0.270833   0.257816   0.310265
# min     0.000000   0.000000   0.000000
# 25%     0.250000   0.375000   0.250000
# 50%     0.333333   0.500000   0.562500
# 75%     0.555556   0.625000   0.750000
# max     1.000000   1.000000   1.000000

# %%
inertia = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(test_data_normalized)
    kmeanModel.fit(test_data_normalized)
    inertia.append(kmeanModel.inertia_)

# %%
# Plot the elbow
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.show()

# %%
clusters = 5

kmeans = KMeans(n_clusters=clusters, random_state=0)
kmeans.fit(test_data)

print(test_data[["age", "general health", "ease of activity"]])
print(kmeans.labels_)
# Out:
#     age  general health  ease of activity
# 0    75               5                 3
# 1    59               7                 7
# 2    50               6                 5
# 3    25               8                 8
# 4    21               8                 9
# 5    28               8                 5
# 6    19               9                10
# 7    64               6                 3
# 8    83               3                 0
# 9    49               7                 3
# 10   60               5                 1
# 11   70               4                 6
# 12   47               6                 2
# 13   24               8                 3
# 14   22               5                 1
# 15   18               8                 3
# 16   56               8                 9
# 17   80               3                 2
# 18   50               3                 2
# 19   47               7                 8
# 20   36               5                 6
# 21   32               6                 4
# 22   71               1                 3
# 23   67               4                 6
# 24   63               7                 7
# 25   26               8                 2
# 26   28               9                 9
# 27   45               3                 6
# 28   20               9                 1
# 29   65               2                 3
# [0 2 3 1 1 1 1 2 0 3 2 4 3 1 1 1 2 0 3 3 3 1 4 4 2 1 1 3 1 4]
